# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# %%
df=pd.read_csv('titanic_toy.csv')

# %%
df.head()
# Out:
#     Age     Fare  Family  Survived
# 0  22.0   7.2500       1         0
# 1  38.0  71.2833       1         1
# 2  26.0   7.9250       0         1
# 3  35.0  53.1000       1         1
# 4  35.0   8.0500       0         0

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=2)

# %%
x_train
# Out:
#       Age      Fare  Family
# 451   NaN   19.9667       1
# 345  24.0   13.0000       0
# 687  19.0   10.1708       0
# 279  35.0   20.2500       2
# 742  21.0  262.3750       4
# ..    ...       ...     ...
# 534  30.0    8.6625       0
# 584   NaN    8.7125       0
# 493  71.0   49.5042       0
# 527   NaN  221.7792       0
# 168   NaN   25.9250       0
#
# [623 rows x 3 columns]

# %%
x_train['Age_99']=x_train['Age'].fillna(99)
x_train['Age_minus1']=x_train['Age'].fillna(-1)
x_train['Fare_999']=x_train['Fare'].fillna(999)
x_train['Fare_minus1']=x_train['Fare'].fillna(-1)

# %%
print(f" original age varience ={x_train['Age'].var()}")
print(f" after impute 99 age varience ={x_train['Age_99'].var()}")
print(f" after impute -1  age varience ={x_train['Age_minus1'].var()}")

print(f" original fare varience ={x_train['Age'].var()}")
print(f" after impute 999 fare varience= {x_train['Fare_999'].var()}")
print(f" after impute -1  fare varience ={x_train['Fare_minus1'].var()}")
# Out:
#  original age varience =206.20200815590607
#  after impute 99 age varience =982.6275573637581
#  after impute -1  age varience =319.6049202949112
#  original fare varience =206.20200815590607
#  after impute 999 fare varience= 51757.15833336026
#  after impute -1  fare varience =2224.3227540401845

# %%
fig=plt.figure()
ax=fig.add_subplot(111)

x_train['Age'].plot(kind='kde',ax=ax)
x_train['Age_99'].plot(kind='kde',color='red',ax=ax)
x_train['Age_minus1'].plot(kind='kde',color='green',ax=ax)
lines,labels=ax.get_legend_handles_labels()
ax.legend(lines,labels,loc='best')

# %%
fig=plt.figure()
ax=fig.add_subplot(111)

x_train['Fare'].plot(kind='kde',ax=ax)
x_train['Fare_999'].plot(kind='kde',color='red',ax=ax)
x_train['Fare_minus1'].plot(kind='kde',color='green',ax=ax)
lines,labels=ax.get_legend_handles_labels()
ax.legend(lines,labels,loc='best')

# %%
x_train.cov()
# Out:
#                     Age         Fare     Family      Age_99  Age_minus1  \
# Age          206.202008    81.466429  -6.136905  206.202008  206.202008
# Fare          81.466429  2293.162510  18.322922 -110.512446  139.542061
# Family        -6.136905    18.322922   2.686080   -7.814266   -3.484268
# Age_99       206.202008  -110.512446  -7.814266  982.627557 -198.935115
# Age_minus1   206.202008   139.542061  -3.484268 -198.935115  319.604920
# Fare_999     181.561673  2293.162510   8.860608 -192.911908  289.202593
# Fare_minus1   72.598339  2293.162510  17.585634 -101.206463  126.202304
#
#                  Fare_999  Fare_minus1
# Age            181.561673    72.598339
# Fare          2293.162510  2293.162510
# Family           8.860608    17.585634
# Age_99        -192.911908  -101.206463
# Age_minus1     289.202593   126.202304
# Fare_999     51757.158333   436.312999
# Fare_minus1    436.312999  2224.322754

# %%
x_train.corr()
# Out:
#                   Age      Fare    Family    Age_99  Age_minus1  Fare_999  \
# Age          1.000000  0.109583 -0.282196  1.000000    1.000000  0.054184
# Fare         0.109583  1.000000  0.230306 -0.073204    0.162679  1.000000
# Family      -0.282196  0.230306  1.000000 -0.152102   -0.118917  0.023764
# Age_99       1.000000 -0.073204 -0.152102  1.000000   -0.354985 -0.027051
# Age_minus1   1.000000  0.162679 -0.118917 -0.354985    1.000000  0.071107
# Fare_999     0.054184  1.000000  0.023764 -0.027051    0.071107  1.000000
# Fare_minus1  0.099686  1.000000  0.227510 -0.068457    0.149679  0.040664
#
#              Fare_minus1
# Age             0.099686
# Fare            1.000000
# Family          0.227510
# Age_99         -0.068457
# Age_minus1      0.149679
# Fare_999        0.040664
# Fare_minus1     1.000000

# %% [markdown]
# # arbitiary impute using sklearn

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=2)

# %%
trf=ColumnTransformer([
    ('impute1',SimpleImputer(strategy='constant',fill_value=99),['Age']),
        ('impute2',SimpleImputer(strategy='constant',fill_value=999),['Fare'])

],remainder='passthrough')

# %%
trf.fit(x_train)
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('impute1',
#                                  SimpleImputer(fill_value=99,
#                                                strategy='constant'),
#                                  ['Age']),
#                                 ('impute2',
#                                  SimpleImputer(fill_value=999,
# ...

# %%
trf.named_transformers_['impute1'].statistics_
# Out:
# array([99.])

# %%
trf.named_transformers_['impute2'].statistics_
x_train
# Out:
#       Age      Fare  Family
# 451   NaN   19.9667       1
# 345  24.0   13.0000       0
# 687  19.0   10.1708       0
# 279  35.0   20.2500       2
# 742  21.0  262.3750       4
# ..    ...       ...     ...
# 534  30.0    8.6625       0
# 584   NaN    8.7125       0
# 493  71.0   49.5042       0
# 527   NaN  221.7792       0
# 168   NaN   25.9250       0
#
# [623 rows x 3 columns]

# %%
x_train=trf.transform(x_train)
x_test=trf.transform(x_test)

# %%
x_train
# Out:
# array([[ 99.    ,  19.9667,   1.    ],
#        [ 24.    ,  13.    ,   0.    ],
#        [ 19.    ,  10.1708,   0.    ],
#        ...,
#        [ 71.    ,  49.5042,   0.    ],
#        [ 99.    , 221.7792,   0.    ],
#        [ 99.    ,  25.925 ,   0.    ]])
